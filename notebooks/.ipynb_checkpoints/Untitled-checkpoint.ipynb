# %%
# %load_ext watermark
# %watermark -v -n -m -p numpy,scipy,sklearn,pandas
# Out:
# Sat Jun 13 2020
#
# CPython 3.8.3
# IPython 7.13.0
#
# numpy 1.18.1
# scipy not installed
# sklearn not installed
# pandas 1.0.3
#
# compiler   : Clang 10.0.0
# system     : Darwin
# release    : 19.4.0
# machine    : x86_64
# processor  : i386
# CPU cores  : 8
# interpreter: 64bit

# %%
import sys
import os
PROJ_ROOT = os.path.abspath(os.path.join(os.pardir))
sys.path.append(os.path.join(PROJ_ROOT, "src"))

# %%
#from models.decision_tree import DecisionTree
import pandas as pd
import numpy as np

# %%
df1 = pd.read_excel(os.path.join(PROJ_ROOT, "data","processed","validate_data.xlsx"),index_col =0)
header = df1.columns.values.tolist()
labels = df1[["G3"]]

# %%
predictions = [13, 11, 12, 11, 13, 12, 10, 10, 12, 11, 16, 13, 9, 11, 12, 12, 13, 13, 12, 11, 13, 13, 11, 10, 11, 10, 10, 11, 12, 14, 13, 12, 13, 13, 12, 11, 13, 13, 13, 14, 10, 14, 14, 12, 14, 13, 17, 13, 10, 11, 13, 11, 16, 10, 12, 10, 11, 11, 13, 13, 10, 13, 13, 11, 13, 13, 16, 13, 13, 14, 12, 12, 11, 13, 12, 12, 10, 12, 10, 13, 10, 10, 11, 13, 11, 12, 10, 13, 13, 13, 13, 11, 10, 14, 10, 10, 11, 13, 10, 11, 13, 13, 12, 13, 14, 13, 16, 16, 13, 12, 15, 13, 12, 13, 10, 10, 10, 12, 14, 11, 13, 10, 11, 13, 11, 13, 10, 10, 13]
TSS = np.sum((np.array(labels) - np.array(labels).mean())** 2)
ESS = np.sum((np.array(predictions) - np.array(labels).mean()) ** 2)

ESS/TSS
# Out:
# 0.49824720117607135

# %%
from models.utils import class_counts,is_numeric,partition,gini,gini_impurity,unique_vals
from models.decision_tree import DecisionTree,DecisionTree,Leaf,Question
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-2a8debb27a09> in <module>
#       1 from models.utils import class_counts,is_numeric,partition,gini,gini_impurity,unique_vals
# ----> 2 from models.decision_tree import DecisionTree,DecisionTree,Leaf,Question
#
# ~/Desktop/random_forest/RandomForest/src/models/decision_tree.py in <module>
#       3
#       4 import logging
# ----> 5 from utils import class_counts,is_numeric,partition,gini,gini_impurity,unique_vals
#       6 import pandas as pd
#       7
#
# ModuleNotFoundError: No module named 'utils'

# %%
import sys
sys.path.append('src')

import pandas as pd
import logging

logger = logging.getLogger(__name__)
GINI_IMPURITY = "gini"
INFO_GAIN = 'info_gain'

class DecisionTree: 
    
    def __init__(self,metrics=None, max_depth=None,nodes=None,leafs=None):
        
        if metrics is None:
            self.metrics = GINI_IMPURITY 
            
        self.max_depth = max_depth
        self.nodes = nodes
   
        if leafs is None:
            self.leafs = []
        
        
        
    def build_tree(self,train_data,header,count=0):
        
        """Builds the tree.
    
        Rules of recursion: 1) Believe that it works. 2) Start by checking
        for the base case (no further information gain). 3) Prepare for
        giant stack traces.
        """
        
        # Try partitioing the dataset on each of the unique attribute,
        # calculate the information gain,
        # and return the question that produces the highest gain.
        
        #print("n° features: {}".format(len(train_data[0]) - 1))
        gain, question = self.find_best_split(train_data,header)
        #print("--input data: {}".format(train_data))
        logger.info("--best question is ''{}'' with information gain: {}".format(question,round(gain,2)))
        # Base case: no further info gain
        # Since we can ask no further questions,
        # we'll return a leaf.
        
        print("--",count)
        print("--",gain)
        
        if isinstance(train_data,pd.DataFrame):
            train_data = train_data.values.tolist()
            
        if gain < 0.001:
            print("final_gain=",gain)
            self.nodes = Leaf(train_data)
            self.leafs.append(Leaf(train_data))
            return DecisionTree(self.metrics, self.max_depth, self.nodes, self.leafs)
        
        if count == self.max_depth:
            print("final_depth=",count)
            self.nodes = Leaf(train_data)
            self.leafs.append(Leaf(train_data))
            return DecisionTree(self.metrics, self.max_depth, self.nodes, self.leafs)
    
        # If we reach here, we have found a useful feature / value
        # to partition on.
        true_rows, false_rows = partition(train_data, question)
        #print("::PARTITION RESULT::\ntrue: {};\nfalse: {}\n".format(true_rows, false_rows))
        
        # Recursively build the true branch.
        logger.info("\n----TRUE BRANCH----")
        true_branch = self.build_tree(true_rows,header,count+1)
        
        # Recursively build the false branch.
        logger.info("\n----FALSE BRANCH----")
        false_branch = self.build_tree(false_rows,header,count+1)
        
        # Return a Question node.
        # This records the best feature / value to ask at this point,
        # as well as the branches to follow
        # dependingo on the answer.
        self.nodes = DecisionNode(question, true_branch, false_branch)
        
        return DecisionTree(self.metrics, self.max_depth, self.nodes, self.leafs)
    
    
    def initialize_split(self,train_data):
        
        if self.metrics == GINI_IMPURITY:
            # Calculate the information gain from this split
            current_uncertainty = gini(train_data)
               
        if self.metrics == INFO_GAIN:
            # TODO:
            pass
        
        return current_uncertainty
        
    def find_best_split(self,train_data,header):
        """Find the best question to ask by iterating over every feature / value
        and calculating the information gain."""
    
        if isinstance(train_data,pd.DataFrame):
            train_data = train_data.values.tolist()
        
        N_FEATURES = len(train_data[0]) - 1  # number of columns
        
        best_gain = 0  # keep track of the best information gain
        best_question = None  # keep train of the feature / value that produced it
        current_uncertainty = self.initialize_split(train_data)
        
        for col in range(N_FEATURES):  # for each feature
            
            values = unique_vals(train_data, col)  # unique values in the column
            logger.info("values features n° {} ''{}'': {}".format(col+1,header[col],values))
            for val in values:  # for each value
        
                question = Question(header,col, val)
                
                # try splitting the dataset
                true_rows, false_rows = partition(train_data, question)
                
                # Skip this split if it doesn't divide the dataset.
                if len(true_rows) == 1 or len(false_rows) == 1:
                    
                    continue
                
                if self.metrics == GINI_IMPURITY:
                    # Calculate the information gain from this split
                    gain = gini_impurity(true_rows, false_rows, current_uncertainty)
               
                if self.metrics == INFO_GAIN:
                    # TODO:
                    pass
               
                if gain >= best_gain:
                    best_gain, best_question = gain, question
    
        return best_gain, best_question


    def classify(self,row):
        """See the 'rules of recursion' above."""

        # Base case: we've reached a leaf
        if isinstance(self.nodes, Leaf):
            logger.info("predictions: {} ".format(self.nodes.predictions))
            return self.nodes.predictions
    
        logger.info("tree_classifier->classify:",self.nodes.question)
        
        #print("input value {}".format(row[node.question.column]))
        print(self)
        print(self.nodes)
        logger.info(self.nodes.question.match(row))
        if node.question.match(row):
            if isinstance(node, DecisionTree):
                logger.info("yes")
                return self.nodes.classify(row, node.true_branch)
            if isinstance(node, DecisionNode):
                logger.info("yes")
                return self.classify(row, node.true_branch)
        else:
            if isinstance(node, DecisionTree):
                logger.info("no")
                return self.nodes.classify(row, node.false_branch)
            if isinstance(node, DecisionNode):
                logger.info("no")
                return self.classify(row, node.false_branch)
    
    def classify_1(self,row, node):
        """See the 'rules of recursion' above."""
        if isinstance(node, Leaf):
            logger.info("predictions: {} ".format(node.predictions))
            return node.predictions
        
        #print("input value {}".format(row[node.question.column]))
    
        if isinstance(node, DecisionTree): 
            # Base case: we've reached a leaf
            if isinstance(node, Leaf):
                logger.info("predictions: {} ".format(node.nodes.predictions))
                return node.nodes.predictions
        
            logger.info("tree_classifier->classify:",node.nodes.question)
            if node.nodes.question.match(row):
                return self.classify_1(row, node.nodes.true_branch)
            else:
                return self.classify_1(row, node.nodes.false_branch)
            
        if isinstance(node, DecisionNode):
        
            logger.info("tree_classifier->classify:",node.question)
            if node.question.match(row):
                return self.classify_1(row, node.true_branch)
            else:
                return self.classify_1(row, node.false_branch)
    
    def print_leaf(counts):
        """A nicer way to print the predictions at a leaf."""
        total = sum(counts.values()) * 1.0
        probs = {}
        for lbl in counts.keys():
            probs[lbl] = str(int(counts[lbl] / total * 100)) + "%"
        return probs
    
    
    def print_tree(self,node, spacing=""):
        """World's most elegant tree printing function."""
    
        # Base case: we've reached a leaf
        if isinstance(node, Leaf):
            print (spacing + "Predict", node.predictions)
            return
    
        # Print the question at this node
        print (spacing + str(node.question))
    
        # Call this function recursively on the true branch
        print (spacing + '--> True:')
        self.print_tree(node.true_branch, spacing + "  ")
    
        # Call this function recursively on the false branch
        print (spacing + '--> False:')
        self.print_tree(node.false_branch, spacing + "  ")
        
    
class Question:
    """A Question is used to partition a dataset.

    This class just records a 'column number' (e.g., 0 for Color) and a
    'column value' (e.g., Green). The 'match' method is used to compare
    the feature value in an example to the feature value stored in the
    question. See the demo below.
    """

    def __init__(self,header, column, value):
        self.header = header
        self.column = column
        self.value = value
        

    def match(self, example):
        # Compare the feature value in an example to the
        # feature value in this question.
        
        val = example[self.column]
        #print("valore domanda {}".format(self.value))
        #print("::input value {}::".format(val))
        if is_numeric(val):
            return val >= self.value
        else:
            return val == self.value

    def __repr__(self):
        # This is just a helper method to print
        # the question in a readable format.
        condition = "=="
        if is_numeric(self.value):
            condition = ">="
        return "Is %s %s %s?" % (
            self.header[self.column], condition, str(self.value))
 
    
class Leaf:
    """A Leaf node classifies data.

    This holds a dictionary of class (e.g., "Apple") -> number of times
    it appears in the rows from the training data that reach this leaf.
    """

    def __init__(self, rows):
        self.predictions = class_counts(rows)
        
   # def __repr__(self):
   #     return str(self.predictions)
  
    
class DecisionNode:
    """A Decision Node asks a question.

    This holds a reference to the question, and to the two child nodes.
    """

    def __init__(self,
                 question,
                 true_branch,
                 false_branch):
        
        self.question = question
        self.true_branch = true_branch
        self.false_branch = false_branch

# %%
dt = DecisionTree()

# %%
dt = dt.build_tree(df1,df1.columns.values)
# Out:
# -- 0
# -- 0.11716158855152903
# -- 1
# -- 0.1152524254401725
# -- 2
# -- 0.20132325141776936
# -- 3
# -- 0.2666666666666667
# -- 4
# -- 0.48
# -- 5
# -- 0.0
# final_gain= 0.0
# -- 5
# -- 0.0
# final_gain= 0.0
# -- 4
# -- 0.4444444444444445
# -- 5
# -- 0.0
# final_gain= 0.0
# -- 5
# -- 0.0
# final_gain= 0.0
# -- 3
# -- 0.22500000000000003
# -- 4
# -- 0.0
# final_gain= 0.0
# -- 4
# -- 0.07999999999999993
# -- 5
# -- 0.0
# final_gain= 0.0
# -- 5
# -- 0.0
# final_gain= 0.0
# -- 2
# -- 0.10243803879310343
# -- 3
# -- 0.0
# final_gain= 0.0
# -- 3
# -- 0.08866637461668436
# -- 4
# -- 0.1866666666666665
# -- 5
# -- 0.0
# final_gain= 0.0
# -- 5
# -- 0.0
# final_gain= 0.0
# -- 4
# -- 0.08801309493830281
# -- 5
# -- 0.2203856749311295
# -- 6
# -- 0.1111111111111111
# -- 7
# -- 0.5
# -- 8
# -- 0.0
# final_gain= 0.0
# -- 8
# -- 0.0
# final_gain= 0.0
# -- 7
# -- 0.0
# final_gain= 0.0
# -- 6
# -- 0.0
# final_gain= 0.0
# -- 5
# -- 0.31250000000000006
# -- 6
# -- 0.0
# final_gain= 0.0
# -- 6
# -- 0.0
# final_gain= 0.0
# -- 1
# -- 0.09510459280442024
# -- 2
# -- 0.04644322027753445
# -- 3
# -- 0.08377025385823028
# -- 4
# -- 0.0
# final_gain= 0.0
# -- 4
# -- 0.04013676230117441
# -- 5
# -- 0.0
# final_gain= 0.0
# -- 5
# -- 0.028702709153836964
# -- 6
# -- 0.0295475530932596
# -- 7
# -- 0.0
# final_gain= 0.0
# -- 7
# -- 0.0
# final_gain= 0.0
# -- 6
# -- 0.09382716049382722
# -- 7
# -- 0.5
# -- 8
# -- 0.0
# final_gain= 0.0
# -- 8
# -- 0.0
# final_gain= 0.0
# -- 7
# -- 0.11999999999999983
# -- 8
# -- 0.0
# final_gain= 0.0
# -- 8
# -- 0.0
# final_gain= 0.0
# -- 3
# -- 0.13860544217687076
# -- 4
# -- 0.21875
# -- 5
# -- 0.375
# -- 6
# -- 0.0
# final_gain= 0.0
# -- 6
# -- 0.0
# final_gain= 0.0
# -- 5
# -- 0.0
# final_gain= 0.0
# -- 4
# -- 0.36111111111111116
# -- 5
# -- 0.0
# final_gain= 0.0
# -- 5
# -- 0.125
# -- 6
# -- 0.0
# final_gain= 0.0
# -- 6
# -- 0.0
# final_gain= 0.0
# -- 2
# -- 0.17839102719277022
# -- 3
# -- 0.1654245408570667
# -- 4
# -- 0.23883808499193107
# -- 5
# -- 0.0
# final_gain= 0.0
# -- 5
# -- 0.07438016528925631
# -- 6
# -- 0.0
# final_gain= 0.0
# -- 6
# -- 0.0
# final_gain= 0.0
# -- 4
# -- 0.375
# -- 5
# -- 0.0
# final_gain= 0.0
# -- 5
# -- 0.0
# final_gain= 0.0
# -- 3
# -- 0.10857142857142854
# -- 4
# -- 0.0
# final_gain= 0.0
# -- 4
# -- 0.1020408163265307
# -- 5
# -- 0.0
# final_gain= 0.0
# -- 5
# -- 0.0
# final_gain= 0.0

# %%
dt.classify_1(df1.values.tolist()[0],dt.nodes)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-fda4198f6553> in <module>
# ----> 1 dt.classify_1(df1.values.tolist()[0],dt.nodes)
#
# <ipython-input-12-69ca8d05ceaa> in classify_1(self, row, node)
#     194             logger.info("tree_classifier->classify:",node.question)
#     195             if node.question.match(row):
# --> 196                 return self.classify_1(row, node.true_branch)
#     197             else:
#     198                 return self.classify_1(row, node.false_branch)
#
# <ipython-input-12-69ca8d05ceaa> in classify_1(self, row, node)
#     182             logger.info("tree_classifier->classify:",node.nodes.question)
#     183             if node.nodes.question.match(row):
# --> 184                 return self.classify_1(row, node.nodes.true_branch)
#     185             else:
#     186                 return self.classify_1(row, node.nodes.false_branch)
#
# <ipython-input-12-69ca8d05ceaa> in classify_1(self, row, node)
#     184                 return self.classify_1(row, node.nodes.true_branch)
#     185             else:
# --> 186                 return self.classify_1(row, node.nodes.false_branch)
#     187
#     188         if isinstance(node, DecisionNode):
#
# <ipython-input-12-69ca8d05ceaa> in classify_1(self, row, node)
#     184                 return self.classify_1(row, node.nodes.true_branch)
#     185             else:
# --> 186                 return self.classify_1(row, node.nodes.false_branch)
#     187
#     188         if isinstance(node, DecisionNode):
#
# <ipython-input-12-69ca8d05ceaa> in classify_1(self, row, node)
#     184                 return self.classify_1(row, node.nodes.true_branch)
#     185             else:
# --> 186                 return self.classify_1(row, node.nodes.false_branch)
#     187
#     188         if isinstance(node, DecisionNode):
#
# <ipython-input-12-69ca8d05ceaa> in classify_1(self, row, node)
#     180                 return node.predictions
#     181
# --> 182             logger.info("tree_classifier->classify:",node.nodes.question)
#     183             if node.nodes.question.match(row):
#     184                 return self.classify_1(row, node.nodes.true_branch)
#
# AttributeError: 'Leaf' object has no attribute 'question'
